# %%
import pandas as pd

# %%
df=pd.read_csv('Online Retail.csv', sep = ',',encoding = "ISO-8859-1", header= 0)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null object
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# 12584,15311,13047 diff customerid
st=set()
for i in range(len(df)):
    if df['CustomerID'][i]==12583:
        st.add((df['InvoiceNo'][i],df['Country'][i]))
print(st)
# Out:
# {('567552', 'France'), ('536370', 'France'), ('569120', 'France'), ('543625', 'France'), ('540455', 'France'), ('577687', 'France'), ('575067', 'France'), ('557627', 'France'), ('570851', 'France'), ('554134', 'France'), ('581001', 'France'), ('C543992', 'France'), ('564471', 'France'), ('C568244', 'France'), ('C571127', 'France'), ('556463', 'France'), ('559441', 'France'), ('546373', 'France')}

# %%
# creating dic of customers
dic=dict()
ctr=0
chk=df['CustomerID'].isnull()
for i in range(len(df)):
    if chk[i]==False:
        ctr+=1
        if df['CustomerID'][i] not in dic:
            dic[df['CustomerID'][i]]=dict()
            dic[df['CustomerID'][i]]['Country']=df['Country'][i]
            dic[df['CustomerID'][i]]['InvoiceNo']=set([(df['InvoiceNo'][i],df['InvoiceDate'][i])])
        else:
            dic[df['CustomerID'][i]]['InvoiceNo'].add((df['InvoiceNo'][i],df['InvoiceDate'][i]))

# print(dic)
print(ctr)

# df['InvoiceNo'].isnull().values.any()
# Out:
# 406829

# %%
for key in dic:
    dic[key]['InvoiceNo']=list(dic[key]['InvoiceNo'])
dic

#using this dic to generate attributes values
# Out:
# {17850.0: {'Country': 'United Kingdom',
#   'InvoiceNo': [('536688', '02-12-2010 12:24'),
#    ('536631', '02-12-2010 10:58'),
#    ('536791', '02-12-2010 15:27'),
#    ('536372', '01-12-2010 09:01'),
#    ('536690', '02-12-2010 12:25'),
#    ('536751', '02-12-2010 14:05'),
#    ('536787', '02-12-2010 15:24'),
#    ('536377', '01-12-2010 09:34'),
#    ('536789', '02-12-2010 15:25'),
#    ('536630', '02-12-2010 10:56'),
#    ('536396', '01-12-2010 10:51'),
#    ('536790', '02-12-2010 15:26'),
#    ('536375', '01-12-2010 09:32'),
#    ('536753', '02-12-2010 14:07'),
#    ('536399', '01-12-2010 10:52'),
#    ('536693', '02-12-2010 12:26'),
#    ('536600', '02-12-2010 08:32'),
#    ('536373', '01-12-2010 09:02'),
#    ('536614', '02-12-2010 09:44'),
#    ('536609', '02-12-2010 09:41'),
#    ('C543611', '10-02-2011 14:38'),
#    ('536628', '02-12-2010 10:54'),
#    ('536603', '02-12-2010 08:40'),
#    ('536629', '02-12-2010 10:55'),
#    ('536601', '02-12-2010 08:33'),
# ...

# %% [markdown]
# # Items.csv

# %%
# data for books.csv

df1=pd.read_csv('shoes.csv')
df1.columns=['Description','UnitPrice']
df1.head()
# Out:
#                                          Description UnitPrice
# 0                       \r\n    \r\n    \r\n               399
# 1                           Shop one-of-a-kind shoes       474
# 2                                       \r\n    \r\n       360
# 3  layasa Men's Air Series Mesh Casual,Walking,Ru...       435
# 4       ASIAN Shoes Wonder-13 Grey Firozi Mesh Shoes       399

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 2 columns):
# Description    229 non-null object
# UnitPrice      229 non-null object
# dtypes: object(2)
# memory usage: 3.7+ KB

# %%
# random customer chosen from cust
cust=[key for key in dic]
cust
# Out:
# [17850.0,
#  13047.0,
#  12583.0,
#  13748.0,
#  15100.0,
#  15291.0,
#  14688.0,
#  17809.0,
#  15311.0,
#  14527.0,
#  16098.0,
#  18074.0,
#  17420.0,
#  16029.0,
#  16250.0,
#  12431.0,
#  17511.0,
#  17548.0,
#  13705.0,
#  13747.0,
#  13408.0,
#  13767.0,
#  17924.0,
#  13448.0,
#  15862.0,
#  15513.0,
#  12791.0,
#  16218.0,
#  14045.0,
#  14307.0,
#  17908.0,
#  17920.0,
#  12838.0,
#  13255.0,
#  16583.0,
#  18085.0,
#  13758.0,
#  13694.0,
#  15983.0,
#  14849.0,
#  17968.0,
#  16210.0,
#  17897.0,
#  17377.0,
#  16552.0,
#  17181.0,
#  17951.0,
#  14729.0,
#  12748.0,
#  15012.0,
#  12868.0,
#  17572.0,
#  14078.0,
#  14001.0,
#  12662.0,
#  15525.0,
#  14237.0,
#  17905.0,
#  15485.0,
#  12433.0,
#  16955.0,
#  15350.0,
#  15605.0,
#  18144.0,
#  15922.0,
#  14594.0,
#  15165.0,
#  14911.0,
#  16456.0,
#  17841.0,
#  12472.0,
#  17346.0,
#  17643.0,
#  17873.0,
#  13093.0,
#  12921.0,
#  13468.0,
#  17760.0,
#  16928.0,
#  16048.0,
#  16274.0,
#  14496.0,
#  14696.0,
# ...

# %%
import random
InvoiceNo=[]
InvoiceDate=[]
CustomerID=[]
Country=[]
for _ in range(len(df1)):
    curr_cust=cust[random.randrange(0, len(cust))]
    CustomerID.append(curr_cust)
    Country.append(dic[curr_cust]['Country'])
    ind=random.randrange(0,len(dic[curr_cust]['InvoiceNo']))
    InvoiceNo.append(dic[curr_cust]['InvoiceNo'][ind][0])
    InvoiceDate.append(dic[curr_cust]['InvoiceNo'][ind][1])
    
print(str(InvoiceNo[0])+','+str(InvoiceDate[0])+','+str(CustomerID[0])+','+str(Country[0]))
# Out:
# 549310,08-04-2011 09:20,16325.0,United Kingdom

# %%
dic[17850] #validating data for some customerID
# Out:
# {'Country': 'United Kingdom',
#  'InvoiceNo': [('536688', '02-12-2010 12:24'),
#   ('536631', '02-12-2010 10:58'),
#   ('536791', '02-12-2010 15:27'),
#   ('536372', '01-12-2010 09:01'),
#   ('536690', '02-12-2010 12:25'),
#   ('536751', '02-12-2010 14:05'),
#   ('536787', '02-12-2010 15:24'),
#   ('536377', '01-12-2010 09:34'),
#   ('536789', '02-12-2010 15:25'),
#   ('536630', '02-12-2010 10:56'),
#   ('536396', '01-12-2010 10:51'),
#   ('536790', '02-12-2010 15:26'),
#   ('536375', '01-12-2010 09:32'),
#   ('536753', '02-12-2010 14:07'),
#   ('536399', '01-12-2010 10:52'),
#   ('536693', '02-12-2010 12:26'),
#   ('536600', '02-12-2010 08:32'),
#   ('536373', '01-12-2010 09:02'),
#   ('536614', '02-12-2010 09:44'),
#   ('536609', '02-12-2010 09:41'),
#   ('C543611', '10-02-2011 14:38'),
#   ('536628', '02-12-2010 10:54'),
#   ('536603', '02-12-2010 08:40'),
#   ('536629', '02-12-2010 10:55'),
#   ('536601', '02-12-2010 08:33'),
#   ('536612', '02-12-2010 09:44'),
# ...

# %%
# giving random stockcode, qty for each pdct
stock=list(df['StockCode'])
qty=list(df['Quantity'])

StockCode=[]
Quantity=[]

for _ in range(len(df1)):
    StockCode.append(stock[random.randrange(0, len(stock))])
    Quantity.append(qty[random.randrange(0, len(qty))])

StockCode
# Out:
# ['21557',
#  '21430',
#  '21928',
#  '23301',
#  '23353',
#  '23192',
#  '23301',
#  '72800D',
#  '23390',
#  '20969',
#  '84452',
#  '21930',
#  '84947',
#  '82484',
#  '22817',
#  '22088',
#  '84029E',
#  '23298',
#  '21026',
#  '21770',
#  '90014B',
#  '22627',
#  '20828',
#  '21064',
#  '23234',
#  '22175',
#  '22907',
#  '22131',
#  '22663',
#  '23343',
#  '20654',
#  '22325',
#  '23341',
#  '21166',
#  '22892',
#  '21901',
#  '84849D',
#  '23190',
#  '22698',
#  '85034B',
#  '23571',
#  '84510C',
#  '22371',
#  '51020B',
#  '22402',
#  '23353',
#  '22286',
#  '22659',
#  '20972',
#  '22992',
#  '22848',
#  '22572',
#  '22378',
#  '85123A',
#  '23263',
#  '23206',
#  '22358',
#  '21136',
#  '22348',
#  '21936',
#  '21977',
#  '22997',
#  '85031A',
#  '85183A',
#  '22748',
#  '22523',
#  '23206',
#  '21217',
#  '21166',
#  '84946',
#  '20839',
#  '85032C',
#  '22114',
#  '22095',
#  '22960',
#  '22819',
#  '23100',
#  '22979',
#  '22556',
#  '23356',
#  '21098',
#  '22913',
# ...

# %%
# clubbing all

df1['InvoiceNo']=InvoiceNo
df1['InvoiceDate']=InvoiceDate
df1['StockCode']=StockCode
df1['Quantity']=Quantity
df1['CustomerID']=CustomerID
df1['Country']=Country

df1.head()
# Out:
#                                          Description UnitPrice InvoiceNo  \
# 0                       \r\n    \r\n    \r\n               399    549310
# 1                           Shop one-of-a-kind shoes       474    568999
# 2                                       \r\n    \r\n       360    566607
# 3  layasa Men's Air Series Mesh Casual,Walking,Ru...       435    570251
# 4       ASIAN Shoes Wonder-13 Grey Firozi Mesh Shoes       399   C573092
#
#         InvoiceDate StockCode  Quantity  CustomerID         Country
# 0  08-04-2011 09:20     21557         1     16325.0  United Kingdom
# 1  29-09-2011 17:34     21430        25     15949.0  United Kingdom
# 2  13-09-2011 16:40     21928        80     13032.0  United Kingdom
# 3  10-10-2011 09:06     23301         1     17025.0  United Kingdom
# 4  27-10-2011 14:38     23353         3     13791.0  United Kingdom

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
df1 = df1[['InvoiceNo','StockCode','Description','Quantity','InvoiceDate','UnitPrice','CustomerID','Country']]
df1
# Out:
#     InvoiceNo StockCode                                        Description  \
# 0      549310     21557                       \r\n    \r\n    \r\n
# 1      568999     21430                           Shop one-of-a-kind shoes
# 2      566607     21928                                       \r\n    \r\n
# 3      570251     23301  layasa Men's Air Series Mesh Casual,Walking,Ru...
# 4     C573092     23353       ASIAN Shoes Wonder-13 Grey Firozi Mesh Shoes
# 5      537467     23192      ETHICS Perfect Ultra Lite Sport Shoes for Men
# 6      580731     23301  layasa Men's Air Series Mesh Sports Running Shoes
# 7      576651    72800D  Amico Men's Air Series Mesh Casual,Walking,Run...
# 8      553054     23390  MEGPAR Men' S Mesh White Running Sports Walkin...
# 9      575922     20969    ETHICS Men's Multi-Colored Sports Running Shoes
# 10     546314     84452  Amico Ultralight Sports & Running Shoes for Me...
# 11     575077     21930  LOOK TWICE Men's Casual Canvas Sport Shoes, Co...
# ...

# %%
df1.to_csv(r'shoes1.csv',index = None, header=True) #saving as .csv file

# %%
df_chk=pd.read_csv('shoes1.csv')
df_chk.head()
# Out:
#   InvoiceNo StockCode                                        Description  \
# 0    549310     21557                 \r\r\n    \r\r\n    \r\r\n
# 1    568999     21430                           Shop one-of-a-kind shoes
# 2    566607     21928                                   \r\r\n    \r\r\n
# 3    570251     23301  layasa Men's Air Series Mesh Casual,Walking,Ru...
# 4   C573092     23353       ASIAN Shoes Wonder-13 Grey Firozi Mesh Shoes
#
#    Quantity       InvoiceDate UnitPrice  CustomerID         Country
# 0         1  08-04-2011 09:20       399     16325.0  United Kingdom
# 1        25  29-09-2011 17:34       474     15949.0  United Kingdom
# 2        80  13-09-2011 16:40       360     13032.0  United Kingdom
# 3         1  10-10-2011 09:06       435     17025.0  United Kingdom
# 4         3  27-10-2011 14:38       399     13791.0  United Kingdom
